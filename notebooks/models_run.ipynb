# %%
import pandas as pd
import jax.numpy as jnp
import evofr as ef
from numpyro.infer.autoguide import AutoDelta, AutoMultivariateNormal
from pathlib import Path
import os
from jax import vmap
import jax.numpy as jnp
from jax.nn import softmax
import matplotlib.pyplot as plt
import numpy as np
from pandas.tseries.offsets import Day, BDay

# %%
os.chdir('/Users/eabousam/freq_dynamics/ncov-forecasting-fit') 
cwd = os.getcwd()
# Out:
# '/Users/eabousam/freq_dynamics/ncov-forecasting-fit'

# %% [markdown]
# ## I. Specification of analysis period (Observation dates) and geographical settings

# %%
#Getting sequences data from commit dates
dates = ['2022-01-01', '2022-01-15','2022-02-01','2022-02-15','2022-03-01','2022-03-15',
         '2022-04-01','2022-04-15','2022-05-01','2022-05-15','2022-06-01','2022-06-15',
         '2022-07-01','2022-07-15','2022-08-01','2022-08-15','2022-09-01','2022-09-15',
         '2022-10-01','2022-10-15','2022-11-01','2022-11-15','2022-12-01','2022-12-15']

#specifying location to run model on
locations = ["USA", "United Kingdom", "Brazil","Australia","South Africa", "Japan"]

# %% [markdown]
# ## II. Assigning farameters and forecasting period

# %%
#Parameters and forecasting period
seed_L = 14
forecast_L = 14
forecast_new = 30
ps = [0.95, 0.8, 0.5]
# Get delays
v_names = ['Delta', 
           'Omicron 21L', 
           'Omicron 21K', 
           'Omicron 22A', 
           'Omicron 22B', 
           'Omicron 22C',
           'Omicron 22D',
           'Omicron 22E',
           'Omicron 23A',
           'other']

gen = ef.pad_delays(
    [ef.discretise_gamma(mn=4.4, std=1.2), # Delta
     ef.discretise_gamma(mn=3.1, std=1.2), # Omicron 21L
     ef.discretise_gamma(mn=3.1, std=1.2), # Omicron 21K #3.1 std 1.2 
     ef.discretise_gamma(mn=3.1, std=1.2), # Omicron 22A
     ef.discretise_gamma(mn=3.1, std=1.2), # Omicron 22B
     ef.discretise_gamma(mn=3.1, std=1.2), # Omicron 22C
     ef.discretise_gamma(mn=3.1, std=1.2), # Omicron 22D
     ef.discretise_gamma(mn=3.1, std=1.2), # Omicron 22E
     ef.discretise_gamma(mn=3.1, std=1.2), # Omicron 23A
     ef.discretise_gamma(mn=4.4, std=1.2)] # Other
    )

delays = ef.pad_delays([ef.discretise_lognorm(mn=3.1, std=1.0)])  

basis_fn = ef.Spline(order = 4, k = 10)

# %% [markdown]
# ## III. FGA, GARW, MLR, and Piantham models definition

# %%
# Defining models
#dict for models
model_type = dict()


#Fixed Growth Advantage model for variants
model_type['FGA'] = ef.RenewalModel(gen, delays, seed_L, forecast_new,
                RLik = ef.FixedGA(0.1), #Likelihood on effective reproduction number (GARW depend on R and gen time)
                CLik = ef.ZINegBinomCases(0.05), #Case Likelihood
                SLik = ef.DirMultinomialSeq(100), #Sequence Likelihood
                v_names = v_names,
                basis_fn = basis_fn)

#Varying Growth Advantage Random Walk Model
model_type['GARW'] = ef.RenewalModel(gen, delays, seed_L, forecast_new,
                RLik = ef.GARW(0.1,0.01, prior_family='Normal'), #Likelihood on effective reproduction number (GARW depend on R and gen time)
                CLik = ef.ZINegBinomCases(0.05), #Case Likelihood
                SLik = ef.DirMultinomialSeq(100), #Sequence Likelihood
                v_names = v_names,
                basis_fn = basis_fn)

#Multinomial Logistic regression model
model_type['MLR'] = ef.MultinomialLogisticRegression(tau=4.2)

#Piantham model
model_type['Piantham'] = ef.models.PianthamModel(gen = ef.discretise_gamma(mn=3.1, std=1.2), forecast_L = forecast_new+14)

# defining inference method
svi = ef.InferMAP(iters = 50_000, lr = 4e-3)

# %% [markdown]
# ## IV. Naive Model specification

# %%
def naive_forecast(seq_count_date, pivot, period=60):
    
    #defining forecast and nowcast dates from pivot date
    forecast_dates = pd.to_datetime(pd.unique(pd.date_range(start = pivot, periods=period, freq ='D') + Day(1))).astype(str)
    #print(forecast_dates)
    nowcast_dates = pd.to_datetime(pd.unique(pd.date_range(end = pivot, periods=period, freq ='D'))).astype(str)
    #print(forecast_dates)
    #defining prediction period for nowcasting and forecasting
    

    #pred_dates = pd.concat((nowcast_dates, forecast_dates))
    pred_dates = nowcast_dates.union(forecast_dates)
    #print(pred_dates)
  
    #computing the frequency of variants for each location
    seq_count_date['total_seq'] = seq_count_date.groupby(['date', 'location'])['sequences'].transform('sum')
    seq_count_date['freq'] = seq_count_date['sequences']/seq_count_date['total_seq']
    
    

    
    #Adding pred_dates to date column for each location and variant
    sc_s = []
    for d in pred_dates:
        #defining recent_dates (7) from pivot date for each date in pred_dates
        #recent_dates = pd.to_datetime(pd.unique(pd.date_range(end = d, periods=7, freq ='D') - Day(7))).astype(str) #that have available seq data
        recent_dates = pd.Series(pd.to_datetime(seq_count_date[seq_count_date.date < d].date).unique()).nlargest(n=7).astype(str)
        #print(d,recent_dates)
        #print(d, recent_dates_n)
        #Computing the mean frequency for recent dates
        seq_count_mean = seq_count_date[seq_count_date.date.isin(recent_dates)].groupby(["variant", "location"])["freq"].mean().reset_index()
    
        sc_ = seq_count_mean.copy()
        #adding dates column
        sc_["date"] = d
        sc_s.append(sc_)

    sc = pd.concat(sc_s).sort_values(by=["location", "variant", "date"])
    #adding nowcast and forecast columns
    sc['median_freq_nowcast'] = sc['freq']
    sc['median_freq_forecast'] = sc['freq']
    #matching dates for nowcast and forecast
    sc.loc[sc.date.isin(forecast_dates),'median_freq_nowcast'] = np.nan
    sc.loc[sc.date.isin(nowcast_dates),'median_freq_forecast'] = np.nan

    return sc.reset_index(drop=True)


for pivot in dates:
    seq_count_date = pd.read_csv(f"data/time_stamped/{pivot}/seq_counts_{pivot}.tsv", sep="\t")
    naive_pred = naive_forecast(seq_count_date, pivot)
    print(naive_pred)
    #create files for estimates for each country and pivot date
    for location in locations:
        filepath = f'plot-est2/cast_estimates_full_dummy/{location}/'
        if not os.path.exists(filepath):
            os.makedirs(filepath)
        naive_pred[naive_pred.location == location].to_csv(filepath+f"freq_full_{pivot}.csv", index = False)
# Out:
#      variant        location      freq        date  median_freq_nowcast  \
# 0      Delta       Australia  1.000000  2021-11-03                  1.0
# 1      Delta       Australia  1.000000  2021-11-04                  1.0
# 2      Delta       Australia  1.000000  2021-11-05                  1.0
# 3      Delta       Australia  1.000000  2021-11-06                  1.0
# 4      Delta       Australia  1.000000  2021-11-07                  1.0
# ...      ...             ...       ...         ...                  ...
# 1857   other  United Kingdom  0.001226  2022-02-26                  NaN
# 1858   other  United Kingdom  0.001226  2022-02-27                  NaN
# 1859   other  United Kingdom  0.001226  2022-02-28                  NaN
# 1860   other  United Kingdom  0.001226  2022-03-01                  NaN
# 1861   other  United Kingdom  0.001226  2022-03-02                  NaN
#
#       median_freq_forecast
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 1857              0.001226
# 1858              0.001226
# 1859              0.001226
# 1860              0.001226
# 1861              0.001226
#
# [1862 rows x 6 columns]
#      variant        location      freq        date  median_freq_nowcast  \
# 0      Delta       Australia  1.000000  2021-11-17                  1.0
# 1      Delta       Australia  1.000000  2021-11-18                  1.0
# 2      Delta       Australia  1.000000  2021-11-19                  1.0
# 3      Delta       Australia  1.000000  2021-11-20                  1.0
# 4      Delta       Australia  1.000000  2021-11-21                  1.0
# ...      ...             ...       ...         ...                  ...
# 2342   other  United Kingdom  0.000734  2022-03-12                  NaN
# 2343   other  United Kingdom  0.000734  2022-03-13                  NaN
# 2344   other  United Kingdom  0.000734  2022-03-14                  NaN
# 2345   other  United Kingdom  0.000734  2022-03-15                  NaN
# 2346   other  United Kingdom  0.000734  2022-03-16                  NaN
#
#       median_freq_forecast
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 2342              0.000734
# 2343              0.000734
# 2344              0.000734
# 2345              0.000734
# 2346              0.000734
#
# [2347 rows x 6 columns]
#      variant        location      freq        date  median_freq_nowcast  \
# 0      Delta       Australia  0.971517  2021-12-04             0.971517
# 1      Delta       Australia  0.972603  2021-12-05             0.972603
# 2      Delta       Australia  0.971401  2021-12-06             0.971401
# 3      Delta       Australia  0.967354  2021-12-07             0.967354
# 4      Delta       Australia  0.960621  2021-12-08             0.960621
# ...      ...             ...       ...         ...                  ...
# 2391   other  United Kingdom  0.000596  2022-03-29                  NaN
# 2392   other  United Kingdom  0.000596  2022-03-30                  NaN
# 2393   other  United Kingdom  0.000596  2022-03-31                  NaN
# 2394   other  United Kingdom  0.000596  2022-04-01                  NaN
# 2395   other  United Kingdom  0.000596  2022-04-02                  NaN
#
#       median_freq_forecast
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 2391              0.000596
# 2392              0.000596
# 2393              0.000596
# 2394              0.000596
# 2395              0.000596
#
# [2396 rows x 6 columns]
#      variant        location      freq        date  median_freq_nowcast  \
# 0      Delta       Australia  0.596547  2021-12-18             0.596547
# 1      Delta       Australia  0.533648  2021-12-19             0.533648
# 2      Delta       Australia  0.524920  2021-12-20             0.524920
# 3      Delta       Australia  0.499711  2021-12-21             0.499711
# 4      Delta       Australia  0.482792  2021-12-22             0.482792
# ...      ...             ...       ...         ...                  ...
# 2368   other  United Kingdom  0.001073  2022-04-12                  NaN
# 2369   other  United Kingdom  0.001073  2022-04-13                  NaN
# 2370   other  United Kingdom  0.001073  2022-04-14                  NaN
# 2371   other  United Kingdom  0.001073  2022-04-15                  NaN
# 2372   other  United Kingdom  0.001073  2022-04-16                  NaN
#
#       median_freq_forecast
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 2368              0.001073
# 2369              0.001073
# 2370              0.001073
# 2371              0.001073
# 2372              0.001073
#
# [2373 rows x 6 columns]
#      variant        location      freq        date  median_freq_nowcast  \
# 0      Delta       Australia  0.116764  2022-01-01             0.116764
# 1      Delta       Australia  0.099519  2022-01-02             0.099519
# 2      Delta       Australia  0.094708  2022-01-03             0.094708
# 3      Delta       Australia  0.079957  2022-01-04             0.079957
# 4      Delta       Australia  0.065288  2022-01-05             0.065288
# ...      ...             ...       ...         ...                  ...
# 2168   other  United Kingdom  0.003344  2022-04-26                  NaN
# 2169   other  United Kingdom  0.003344  2022-04-27                  NaN
# 2170   other  United Kingdom  0.003344  2022-04-28                  NaN
# 2171   other  United Kingdom  0.003344  2022-04-29                  NaN
# 2172   other  United Kingdom  0.003344  2022-04-30                  NaN
#
#       median_freq_forecast
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 2168              0.003344
# 2169              0.003344
# 2170              0.003344
# 2171              0.003344
# 2172              0.003344
#
# [2173 rows x 6 columns]
#      variant        location      freq        date  median_freq_nowcast  \
# 0      Delta       Australia  0.039461  2022-01-15             0.039461
# 1      Delta       Australia  0.035271  2022-01-16             0.035271
# 2      Delta       Australia  0.028772  2022-01-17             0.028772
# 3      Delta       Australia  0.025639  2022-01-18             0.025639
# 4      Delta       Australia  0.021536  2022-01-19             0.021536
# ...      ...             ...       ...         ...                  ...
# 2183   other  United Kingdom  0.005631  2022-05-10                  NaN
# 2184   other  United Kingdom  0.005631  2022-05-11                  NaN
# 2185   other  United Kingdom  0.005631  2022-05-12                  NaN
# 2186   other  United Kingdom  0.005631  2022-05-13                  NaN
# 2187   other  United Kingdom  0.005631  2022-05-14                  NaN
#
#       median_freq_forecast
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 2183              0.005631
# 2184              0.005631
# 2185              0.005631
# 2186              0.005631
# 2187              0.005631
#
# [2188 rows x 6 columns]
#      variant        location      freq        date  median_freq_nowcast  \
# 0      Delta       Australia  0.007268  2022-02-01             0.007268
# 1      Delta       Australia  0.007157  2022-02-02             0.007157
# 2      Delta       Australia  0.004127  2022-02-03             0.004127
# 3      Delta       Australia  0.004243  2022-02-04             0.004243
# 4      Delta       Australia  0.004489  2022-02-05             0.004489
# ...      ...             ...       ...         ...                  ...
# 2505   other  United Kingdom  0.007434  2022-05-27                  NaN
# 2506   other  United Kingdom  0.007434  2022-05-28                  NaN
# 2507   other  United Kingdom  0.007434  2022-05-29                  NaN
# 2508   other  United Kingdom  0.007434  2022-05-30                  NaN
# 2509   other  United Kingdom  0.007434  2022-05-31                  NaN
#
#       median_freq_forecast
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 2505              0.007434
# 2506              0.007434
# 2507              0.007434
# 2508              0.007434
# 2509              0.007434
#
# [2510 rows x 6 columns]
#      variant        location      freq        date  median_freq_nowcast  \
# 0      Delta       Australia  0.003012  2022-02-15             0.003012
# 1      Delta       Australia  0.003140  2022-02-16             0.003140
# 2      Delta       Australia  0.003140  2022-02-17             0.003140
# 3      Delta       Australia  0.003140  2022-02-18             0.003140
# 4      Delta       Australia  0.003140  2022-02-19             0.003140
# ...      ...             ...       ...         ...                  ...
# 2574   other  United Kingdom  0.006902  2022-06-10                  NaN
# 2575   other  United Kingdom  0.006902  2022-06-11                  NaN
# 2576   other  United Kingdom  0.006902  2022-06-12                  NaN
# 2577   other  United Kingdom  0.006902  2022-06-13                  NaN
# 2578   other  United Kingdom  0.006902  2022-06-14                  NaN
#
#       median_freq_forecast
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 2574              0.006902
# 2575              0.006902
# 2576              0.006902
# 2577              0.006902
# 2578              0.006902
#
# [2579 rows x 6 columns]
#      variant        location      freq        date  median_freq_nowcast  \
# 0      Delta       Australia  0.003049  2022-03-08             0.003049
# 1      Delta       Australia  0.003049  2022-03-09             0.003049
# 2      Delta       Australia  0.003049  2022-03-10             0.003049
# 3      Delta       Australia  0.003049  2022-03-11             0.003049
# 4      Delta       Australia  0.003049  2022-03-12             0.003049
# ...      ...             ...       ...         ...                  ...
# 2867   other  United Kingdom  0.007917  2022-06-26                  NaN
# 2868   other  United Kingdom  0.007917  2022-06-27                  NaN
# 2869   other  United Kingdom  0.007917  2022-06-28                  NaN
# 2870   other  United Kingdom  0.007917  2022-06-29                  NaN
# 2871   other  United Kingdom  0.007917  2022-06-30                  NaN
#
#       median_freq_forecast
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 2867              0.007917
# 2868              0.007917
# 2869              0.007917
# 2870              0.007917
# 2871              0.007917
#
# [2872 rows x 6 columns]
#           variant        location      freq        date  median_freq_nowcast  \
# 0     Omicron 21K       Australia  0.276919  2022-03-17             0.276919
# 1     Omicron 21K       Australia  0.249885  2022-03-18             0.249885
# 2     Omicron 21K       Australia  0.239713  2022-03-19             0.239713
# 3     Omicron 21K       Australia  0.223095  2022-03-20             0.223095
# 4     Omicron 21K       Australia  0.205906  2022-03-21             0.205906
# ...           ...             ...       ...         ...                  ...
# 3098        other  United Kingdom  0.010669  2022-07-10                  NaN
# 3099        other  United Kingdom  0.010669  2022-07-11                  NaN
# 3100        other  United Kingdom  0.010669  2022-07-12                  NaN
# 3101        other  United Kingdom  0.010669  2022-07-13                  NaN
# 3102        other  United Kingdom  0.010669  2022-07-14                  NaN
#
#       median_freq_forecast
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 3098              0.010669
# 3099              0.010669
# 3100              0.010669
# 3101              0.010669
# 3102              0.010669
#
# [3103 rows x 6 columns]
#           variant        location      freq        date  median_freq_nowcast  \
# 0     Omicron 21K       Australia  0.071136  2022-04-03             0.071136
# 1     Omicron 21K       Australia  0.069418  2022-04-04             0.069418
# 2     Omicron 21K       Australia  0.067568  2022-04-05             0.067568
# 3     Omicron 21K       Australia  0.064842  2022-04-06             0.064842
# 4     Omicron 21K       Australia  0.056586  2022-04-07             0.056586
# ...           ...             ...       ...         ...                  ...
# 3790        other  United Kingdom  0.014104  2022-07-27                  NaN
# 3791        other  United Kingdom  0.014104  2022-07-28                  NaN
# 3792        other  United Kingdom  0.014104  2022-07-29                  NaN
# 3793        other  United Kingdom  0.014104  2022-07-30                  NaN
# 3794        other  United Kingdom  0.014104  2022-07-31                  NaN
#
#       median_freq_forecast
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 3790              0.014104
# 3791              0.014104
# 3792              0.014104
# 3793              0.014104
# 3794              0.014104
#
# [3795 rows x 6 columns]
#           variant        location      freq        date  median_freq_nowcast  \
# 0     Omicron 21K       Australia  0.033389  2022-04-17             0.033389
# 1     Omicron 21K       Australia  0.030771  2022-04-18             0.030771
# 2     Omicron 21K       Australia  0.031461  2022-04-19             0.031461
# 3     Omicron 21K       Australia  0.031579  2022-04-20             0.031579
# 4     Omicron 21K       Australia  0.029201  2022-04-21             0.029201
# ...           ...             ...       ...         ...                  ...
# 4045        other  United Kingdom  0.012026  2022-08-10                  NaN
# 4046        other  United Kingdom  0.012026  2022-08-11                  NaN
# 4047        other  United Kingdom  0.012026  2022-08-12                  NaN
# 4048        other  United Kingdom  0.012026  2022-08-13                  NaN
# 4049        other  United Kingdom  0.012026  2022-08-14                  NaN
#
#       median_freq_forecast
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 4045              0.012026
# 4046              0.012026
# 4047              0.012026
# 4048              0.012026
# 4049              0.012026
#
# [4050 rows x 6 columns]
#           variant        location      freq        date  median_freq_nowcast  \
# 0     Omicron 21K       Australia  0.014206  2022-05-03             0.014206
# 1     Omicron 21K       Australia  0.012202  2022-05-04             0.012202
# 2     Omicron 21K       Australia  0.009618  2022-05-05             0.009618
# 3     Omicron 21K       Australia  0.008817  2022-05-06             0.008817
# 4     Omicron 21K       Australia  0.006450  2022-05-07             0.006450
# ...           ...             ...       ...         ...                  ...
# 3792        other  United Kingdom  0.004231  2022-08-26                  NaN
# 3793        other  United Kingdom  0.004231  2022-08-27                  NaN
# 3794        other  United Kingdom  0.004231  2022-08-28                  NaN
# 3795        other  United Kingdom  0.004231  2022-08-29                  NaN
# 3796        other  United Kingdom  0.004231  2022-08-30                  NaN
#
#       median_freq_forecast
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 3792              0.004231
# 3793              0.004231
# 3794              0.004231
# 3795              0.004231
# 3796              0.004231
#
# [3797 rows x 6 columns]
#           variant        location      freq        date  median_freq_nowcast  \
# 0     Omicron 21K       Australia  0.008460  2022-05-17             0.008460
# 1     Omicron 21K       Australia  0.007606  2022-05-18             0.007606
# 2     Omicron 21K       Australia  0.005844  2022-05-19             0.005844
# 3     Omicron 21K       Australia  0.006318  2022-05-20             0.006318
# 4     Omicron 21K       Australia  0.005073  2022-05-21             0.005073
# ...           ...             ...       ...         ...                  ...
# 3936        other  United Kingdom  0.004437  2022-09-09                  NaN
# 3937        other  United Kingdom  0.004437  2022-09-10                  NaN
# 3938        other  United Kingdom  0.004437  2022-09-11                  NaN
# 3939        other  United Kingdom  0.004437  2022-09-12                  NaN
# 3940        other  United Kingdom  0.004437  2022-09-13                  NaN
#
#       median_freq_forecast
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 3936              0.004437
# 3937              0.004437
# 3938              0.004437
# 3939              0.004437
# 3940              0.004437
#
# [3941 rows x 6 columns]
#      variant        location      freq        date  median_freq_nowcast  \
# 0      Delta       Australia  0.002703  2022-06-15             0.002703
# 1      Delta       Australia  0.002703  2022-06-16             0.002703
# 2      Delta       Australia  0.002703  2022-06-17             0.002703
# 3      Delta       Australia  0.002703  2022-06-18             0.002703
# 4      Delta       Australia  0.002703  2022-06-19             0.002703
# ...      ...             ...       ...         ...                  ...
# 4083   other  United Kingdom  0.003158  2022-09-26                  NaN
# 4084   other  United Kingdom  0.003158  2022-09-27                  NaN
# 4085   other  United Kingdom  0.003158  2022-09-28                  NaN
# 4086   other  United Kingdom  0.003158  2022-09-29                  NaN
# 4087   other  United Kingdom  0.003158  2022-09-30                  NaN
#
#       median_freq_forecast
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 4083              0.003158
# 4084              0.003158
# 4085              0.003158
# 4086              0.003158
# 4087              0.003158
#
# [4088 rows x 6 columns]
#      variant        location      freq        date  median_freq_nowcast  \
# 0      Delta       Australia  0.002653  2022-06-17             0.002653
# 1      Delta       Australia  0.002653  2022-06-18             0.002653
# 2      Delta       Australia  0.002653  2022-06-19             0.002653
# 3      Delta       Australia  0.002653  2022-06-20             0.002653
# 4      Delta       Australia  0.002653  2022-06-21             0.002653
# ...      ...             ...       ...         ...                  ...
# 3857   other  United Kingdom  0.003782  2022-10-10                  NaN
# 3858   other  United Kingdom  0.003782  2022-10-11                  NaN
# 3859   other  United Kingdom  0.003782  2022-10-12                  NaN
# 3860   other  United Kingdom  0.003782  2022-10-13                  NaN
# 3861   other  United Kingdom  0.003782  2022-10-14                  NaN
#
#       median_freq_forecast
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 3857              0.003782
# 3858              0.003782
# 3859              0.003782
# 3860              0.003782
# 3861              0.003782
#
# [3862 rows x 6 columns]
#           variant        location      freq        date  median_freq_nowcast  \
# 0     Omicron 21L       Australia  0.245259  2022-07-04             0.245259
# 1     Omicron 21L       Australia  0.234665  2022-07-05             0.234665
# 2     Omicron 21L       Australia  0.231958  2022-07-06             0.231958
# 3     Omicron 21L       Australia  0.217933  2022-07-07             0.217933
# 4     Omicron 21L       Australia  0.205250  2022-07-08             0.205250
# ...           ...             ...       ...         ...                  ...
# 3722        other  United Kingdom  0.001588  2022-10-27                  NaN
# 3723        other  United Kingdom  0.001588  2022-10-28                  NaN
# 3724        other  United Kingdom  0.001588  2022-10-29                  NaN
# 3725        other  United Kingdom  0.001588  2022-10-30                  NaN
# 3726        other  United Kingdom  0.001588  2022-10-31                  NaN
#
#       median_freq_forecast
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 3722              0.001588
# 3723              0.001588
# 3724              0.001588
# 3725              0.001588
# 3726              0.001588
#
# [3727 rows x 6 columns]
#           variant        location      freq        date  median_freq_nowcast  \
# 0     Omicron 21K       Australia  0.006410  2022-08-20              0.00641
# 1     Omicron 21K       Australia  0.006410  2022-08-21              0.00641
# 2     Omicron 21K       Australia  0.006410  2022-08-22              0.00641
# 3     Omicron 21K       Australia  0.006410  2022-08-23              0.00641
# 4     Omicron 21K       Australia  0.006410  2022-08-24              0.00641
# ...           ...             ...       ...         ...                  ...
# 3650        other  United Kingdom  0.003936  2022-11-10                  NaN
# 3651        other  United Kingdom  0.003936  2022-11-11                  NaN
# 3652        other  United Kingdom  0.003936  2022-11-12                  NaN
# 3653        other  United Kingdom  0.003936  2022-11-13                  NaN
# 3654        other  United Kingdom  0.003936  2022-11-14                  NaN
#
#       median_freq_forecast
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 3650              0.003936
# 3651              0.003936
# 3652              0.003936
# 3653              0.003936
# 3654              0.003936
#
# [3655 rows x 6 columns]
#           variant        location      freq        date  median_freq_nowcast  \
# 0     Omicron 21K       Australia  0.005155  2022-08-20             0.005155
# 1     Omicron 21K       Australia  0.005155  2022-08-21             0.005155
# 2     Omicron 21K       Australia  0.005155  2022-08-22             0.005155
# 3     Omicron 21K       Australia  0.005155  2022-08-23             0.005155
# 4     Omicron 21K       Australia  0.005155  2022-08-24             0.005155
# ...           ...             ...       ...         ...                  ...
# 3584        other  United Kingdom  0.009746  2022-11-26                  NaN
# 3585        other  United Kingdom  0.009746  2022-11-27                  NaN
# 3586        other  United Kingdom  0.009746  2022-11-28                  NaN
# 3587        other  United Kingdom  0.009746  2022-11-29                  NaN
# 3588        other  United Kingdom  0.009746  2022-11-30                  NaN
#
#       median_freq_forecast
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 3584              0.009746
# 3585              0.009746
# 3586              0.009746
# 3587              0.009746
# 3588              0.009746
#
# [3589 rows x 6 columns]
#           variant        location      freq        date  median_freq_nowcast  \
# 0     Omicron 21K       Australia  0.004975  2022-08-20             0.004975
# 1     Omicron 21K       Australia  0.004975  2022-08-21             0.004975
# 2     Omicron 21K       Australia  0.004975  2022-08-22             0.004975
# 3     Omicron 21K       Australia  0.004975  2022-08-23             0.004975
# 4     Omicron 21K       Australia  0.004975  2022-08-24             0.004975
# ...           ...             ...       ...         ...                  ...
# 3634        other  United Kingdom  0.007070  2022-12-10                  NaN
# 3635        other  United Kingdom  0.007070  2022-12-11                  NaN
# 3636        other  United Kingdom  0.007070  2022-12-12                  NaN
# 3637        other  United Kingdom  0.007070  2022-12-13                  NaN
# 3638        other  United Kingdom  0.007070  2022-12-14                  NaN
#
#       median_freq_forecast
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 3634               0.00707
# 3635               0.00707
# 3636               0.00707
# 3637               0.00707
# 3638               0.00707
#
# [3639 rows x 6 columns]
#           variant        location      freq        date  median_freq_nowcast  \
# 0     Omicron 21K       Australia  0.003676  2022-09-03             0.003676
# 1     Omicron 21K       Australia  0.003676  2022-09-04             0.003676
# 2     Omicron 21K       Australia  0.003676  2022-09-05             0.003676
# 3     Omicron 21K       Australia  0.003676  2022-09-06             0.003676
# 4     Omicron 21K       Australia  0.003676  2022-09-07             0.003676
# ...           ...             ...       ...         ...                  ...
# 4232        other  United Kingdom  0.012088  2022-12-27                  NaN
# 4233        other  United Kingdom  0.012088  2022-12-28                  NaN
# 4234        other  United Kingdom  0.012088  2022-12-29                  NaN
# 4235        other  United Kingdom  0.012088  2022-12-30                  NaN
# 4236        other  United Kingdom  0.012088  2022-12-31                  NaN
#
#       median_freq_forecast
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 4232              0.012088
# 4233              0.012088
# 4234              0.012088
# 4235              0.012088
# 4236              0.012088
#
# [4237 rows x 6 columns]
#           variant        location      freq        date  median_freq_nowcast  \
# 0     Omicron 21K       Australia  0.006494  2022-10-03             0.006494
# 1     Omicron 21K       Australia  0.006494  2022-10-04             0.006494
# 2     Omicron 21K       Australia  0.004484  2022-10-05             0.004484
# 3     Omicron 21K       Australia  0.004484  2022-10-06             0.004484
# 4     Omicron 21K       Australia  0.004484  2022-10-07             0.004484
# ...           ...             ...       ...         ...                  ...
# 4427        other  United Kingdom  0.022607  2023-01-10                  NaN
# 4428        other  United Kingdom  0.022607  2023-01-11                  NaN
# 4429        other  United Kingdom  0.022607  2023-01-12                  NaN
# 4430        other  United Kingdom  0.022607  2023-01-13                  NaN
# 4431        other  United Kingdom  0.022607  2023-01-14                  NaN
#
#       median_freq_forecast
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 4427              0.022607
# 4428              0.022607
# 4429              0.022607
# 4430              0.022607
# 4431              0.022607
#
# [4432 rows x 6 columns]
#           variant        location      freq        date  median_freq_nowcast  \
# 0     Omicron 21K       Australia  0.006494  2022-10-03             0.006494
# 1     Omicron 21K       Australia  0.006494  2022-10-04             0.006494
# 2     Omicron 21K       Australia  0.004466  2022-10-05             0.004466
# 3     Omicron 21K       Australia  0.004466  2022-10-06             0.004466
# 4     Omicron 21K       Australia  0.004466  2022-10-07             0.004466
# ...           ...             ...       ...         ...                  ...
# 4405        other  United Kingdom  0.040135  2023-01-26                  NaN
# 4406        other  United Kingdom  0.040135  2023-01-27                  NaN
# 4407        other  United Kingdom  0.040135  2023-01-28                  NaN
# 4408        other  United Kingdom  0.040135  2023-01-29                  NaN
# 4409        other  United Kingdom  0.040135  2023-01-30                  NaN
#
#       median_freq_forecast
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 4405              0.040135
# 4406              0.040135
# 4407              0.040135
# 4408              0.040135
# 4409              0.040135
#
# [4410 rows x 6 columns]
#           variant        location      freq        date  median_freq_nowcast  \
# 0     Omicron 21K       Australia  0.002392  2022-10-17             0.002392
# 1     Omicron 21K       Australia  0.002045  2022-10-18             0.002045
# 2     Omicron 21K       Australia  0.002045  2022-10-19             0.002045
# 3     Omicron 21K       Australia  0.002058  2022-11-01             0.002058
# 4     Omicron 21K       Australia  0.002058  2022-11-02             0.002058
# ...           ...             ...       ...         ...                  ...
# 4380        other  United Kingdom  0.056287  2023-02-09                  NaN
# 4381        other  United Kingdom  0.056287  2023-02-10                  NaN
# 4382        other  United Kingdom  0.056287  2023-02-11                  NaN
# 4383        other  United Kingdom  0.056287  2023-02-12                  NaN
# 4384        other  United Kingdom  0.056287  2023-02-13                  NaN
#
#       median_freq_forecast
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 4380              0.056287
# 4381              0.056287
# 4382              0.056287
# 4383              0.056287
# 4384              0.056287
#
# [4385 rows x 6 columns]

# %% [markdown]
# ## V. Helper functions to export variant frequencies and growth advantages

# %%
#export posterior frequencies forecast and no forecast
def save_freq(samples, variant_data, ps, forecast_date, name, filepath):
    #only need last 14 days
    freq_now = pd.DataFrame(ef.get_freq(samples, variant_data, ps, name=name, forecast = False))
    #Get the freq dates nowcast period
    #nowcast_dates = variant_data.dates[-14:]
    nowcast_dates = variant_data.dates[-60:]
    
    freq_now = freq_now[freq_now['date'].isin(nowcast_dates)]
    freq_fr = pd.DataFrame(ef.get_freq(samples, variant_data, ps, name=name, forecast = True))
    freq_merged = pd.concat([freq_now, freq_fr])
    #freq_now = freq_now.rename(columns = {'median_freq':'median_freq_nowcast','freq_upper_95':'freq_nowcast_upper_95'}, inplace = False)
    
    #rename intervals
    freq_merged = freq_merged.rename(columns = {'median_freq':'median_freq_nowcast','freq_upper_95':'freq_nowcast_upper_95'}, inplace = False)

    freq_merged.to_csv(f'{filepath}/freq_full_{forecast_date}.csv', index = False)
    #freq_now.to_csv(f'{filepath}/freq_nowcast_{forecast_date}.csv', index = False)
    #freq_fr.to_csv(f'{filepath}/freq_forecast_{forecast_date}.csv', index = False)

# %%
#export posterior frequencies forecast and nowcast
def save_mlr_freq(samples, variant_data, ps, forecast_date, name, filepath):

    
    freq_now = pd.DataFrame(ef.get_freq(samples, variant_data, ps, name=name, forecast = False))
    #Get the freq dates nowcast period
    nowcast_dates = variant_data.dates[-60:]
    
    freq_now = freq_now[freq_now['date'].isin(nowcast_dates)]
    
    freq_fr = pd.DataFrame(ef.get_freq(samples, variant_data, ps, name=name, forecast = True))
    freq_merged = pd.concat([freq_now, freq_fr])
    #rename intervals
    freq_merged = freq_merged.rename(columns = {'median_freq':'median_freq_nowcast','freq_upper_95':'freq_nowcast_upper_95'}, inplace = False)

    freq_merged.to_csv(f'{filepath}/freq_full_{forecast_date}.csv', index = False)

# %%
def forecast_frequencies(samples, mlr, forecast_L):
    """
    Use posterior beta to forecast posterior frequenicies.
    """
    
    # Making feature matrix for forecasting
    last_T = samples["freq"].shape[1]
    
    X = mlr.make_ols_feature(start=last_T, stop=last_T + forecast_L)
    # Posterior beta
    beta = jnp.array(samples["beta"])
    
    # Matrix multiplication by sample
    dot_by_sample = vmap(jnp.dot, in_axes=(None, 0), out_axes=0)
    logits = dot_by_sample(X, beta) # Logit frequencies by variant
    return softmax(logits, axis=-1)

# %%
#Growth Advantage

def get_gr_adv(samples, variant_data, ps, name, date, site, filepath):

    growth_adv = pd.DataFrame(ef.posterior.get_site_by_variant(samples, variant_data, ps, name=name, site=site, forecast=False))

    #get growth advantage relative to BA.1 Omicron 21K
    
    
    growth_adv.to_csv(f'{filepath}/full_growth_advantages_{date}.csv',index = False, header = True)
    
    return None

# %%
def get_mlr_gr_adv(samples, variant_data, ps, name,date, filepath):
    

    growth_adv = pd.DataFrame(ef.posterior.get_growth_advantage(samples, variant_data, ps, name=name, rel_to="Omicron 21L"))
    growth_adv.to_csv(f'{filepath}/full_growth_advantages_{date}.csv',index = False, header=True)

    return None

# %% [markdown]
# ## VI. Running models and exporting results

# %%
models = ['GARW','MLR', 'Piantham', 'FGA']
#'Piantham','GARW',, 'FGA'

#function to input models 
def model_run(model):
    for location in locations:
        for date in dates:
            #Output file path
            filepath = f"./plot-est2/cast_estimates_full_{model}/{location}"    
            if not os.path.exists(filepath):
                os.makedirs(filepath)
            #read sequences
            raw_seq = pd.read_csv(f"data/time_stamped/{date}/seq_counts_{date}.tsv", sep="\t")
            raw_cases = pd.read_csv(f"data/time_stamped/{date}/case_counts_{date}.tsv", sep="\t")
            raw_cases = raw_cases[raw_cases.location == location]
            raw_seq = raw_seq[raw_seq.location == location]
            if len(raw_cases)==0:
                continue

            #defining variant data (freq and seq)
            if model == 'MLR':
                variant_data = ef.VariantFrequencies(raw_seq, pivot="Omicron 21L")
                posterior = svi.fit(model_type[model], variant_data)
                posterior.samples["freq_forecast"] = forecast_frequencies(posterior.samples, model_type[model], 74)
                samples = posterior.samples
                save_mlr_freq(posterior.samples, variant_data, ps, date, location, filepath)
                samples = posterior.samples
                get_mlr_gr_adv(samples, variant_data, ps, location, date, filepath)
                
            if model == 'Piantham':
                variant_data = ef.VariantFrequencies(raw_seq, pivot="Omicron 21L")
                posterior = svi.fit(model_type[model], variant_data)
                samples = posterior.samples
                save_freq(posterior.samples, variant_data, ps, date, location, filepath)
                get_mlr_gr_adv(samples, variant_data, ps, location, date, filepath)
            if model == 'FGA':
                variant_data = ef.CaseFrequencyData(raw_cases=raw_cases, raw_seq=raw_seq, pivot="Omicron 21L")
                posterior = svi.fit(model_type[model], variant_data)
                #saving posterior frequencies
                samples = posterior.samples
                save_freq(posterior.samples, variant_data, ps, date, location, filepath)
                #saving growth advantages
                get_mlr_gr_adv(samples, variant_data, ps, location, date, filepath)      
            if model == 'GARW':
                variant_data = ef.CaseFrequencyData(raw_cases=raw_cases, raw_seq=raw_seq, pivot="Omicron 21L")
                posterior = svi.fit(model_type[model], variant_data)
                #saving posterior frequencies
                samples = posterior.samples
                save_freq(posterior.samples, variant_data, ps, date, location, filepath)
                #saving growth advantages
                get_gr_adv(samples, variant_data, ps, location, date, "ga", filepath)

    return None

for model in models:
    model_run(model)
# Out:
# /Users/eabousam/opt/anaconda3/envs/forecasting-fit/lib/python3.9/site-packages/evofr/data/data_helpers.py:89: UserWarning: Omicron 21L not present in variant names. Using provided order.
#   warnings.warn(
# /Users/eabousam/opt/anaconda3/envs/forecasting-fit/lib/python3.9/site-packages/evofr/data/data_helpers.py:89: UserWarning: Omicron 21L not present in variant names. Using provided order.
#   warnings.warn(
# /Users/eabousam/opt/anaconda3/envs/forecasting-fit/lib/python3.9/site-packages/evofr/data/data_helpers.py:89: UserWarning: Omicron 21L not present in variant names. Using provided order.
#   warnings.warn(
# /Users/eabousam/opt/anaconda3/envs/forecasting-fit/lib/python3.9/site-packages/evofr/data/data_helpers.py:89: UserWarning: Omicron 21L not present in variant names. Using provided order.
#   warnings.warn(
# /Users/eabousam/opt/anaconda3/envs/forecasting-fit/lib/python3.9/site-packages/evofr/data/data_helpers.py:89: UserWarning: Omicron 21L not present in variant names. Using provided order.
#   warnings.warn(
# /Users/eabousam/opt/anaconda3/envs/forecasting-fit/lib/python3.9/site-packages/evofr/data/data_helpers.py:89: UserWarning: Omicron 21L not present in variant names. Using provided order.
#   warnings.warn(
# /Users/eabousam/opt/anaconda3/envs/forecasting-fit/lib/python3.9/site-packages/evofr/data/data_helpers.py:89: UserWarning: Omicron 21L not present in variant names. Using provided order.
#   warnings.warn(
# /Users/eabousam/opt/anaconda3/envs/forecasting-fit/lib/python3.9/site-packages/evofr/data/data_helpers.py:89: UserWarning: Omicron 21L not present in variant names. Using provided order.
#   warnings.warn(
# /Users/eabousam/opt/anaconda3/envs/forecasting-fit/lib/python3.9/site-packages/evofr/data/data_helpers.py:89: UserWarning: Omicron 21L not present in variant names. Using provided order.
#   warnings.warn(
# /Users/eabousam/opt/anaconda3/envs/forecasting-fit/lib/python3.9/site-packages/evofr/data/data_helpers.py:89: UserWarning: Omicron 21L not present in variant names. Using provided order.
#   warnings.warn(
# /Users/eabousam/opt/anaconda3/envs/forecasting-fit/lib/python3.9/site-packages/evofr/data/data_helpers.py:89: UserWarning: Omicron 21L not present in variant names. Using provided order.
#   warnings.warn(
# /Users/eabousam/opt/anaconda3/envs/forecasting-fit/lib/python3.9/site-packages/evofr/data/data_helpers.py:89: UserWarning: Omicron 21L not present in variant names. Using provided order.
#   warnings.warn(

# %% [markdown]
# Misc Code

# %%
forecast_dates = pd.to_datetime(pd.unique(pd.date_range(start = date, periods=60, freq ='D') + Day(1))).astype(str)
#print(forecast_dates)
for date in dates:
    nowcast_dates = pd.to_datetime(pd.unique(pd.date_range(end = date, periods=60, freq ='D'))).astype(str)
    #print(nowcast_dates)

recent_dates = pd.to_datetime(pd.unique(pd.date_range(end = date, periods=7, freq ='D') - Day(14))).astype(str)
#print(recent_dates)
#defining prediction period for nowcasting and forecasting
pred_dates = pd.to_datetime(pd.unique(pd.date_range(start = date, periods=120, freq ='D') - Day(60))).astype(str)
#print(pred_dates)
for d in pred_dates:
    #defining recent_dates (7) from pivot date for each date in pred_dates
    for i in range(60):
        recent_dates = pd.to_datetime(pd.unique(pd.date_range(end = date, periods=7, freq ='D') - Day(i))).astype(str)
        #print(recent_dates)
    #Computing the mean frequency for recent dates
    seq_count_mean = seq_count_date[seq_count_date.date.isin(recent_dates)].groupby(["variant", "location"])["freq"].mean().reset_index()

test = pd.to_datetime(pd.unique(pd.date_range(start = date, periods= 60, freq ='D') - Day(14))).astype(str)
print(test)
# Out:
# /Users/eabousam/opt/anaconda3/envs/forecasting-fit/lib/python3.9/site-packages/evofr/data/data_helpers.py:89: UserWarning: Omicron 21L not present in variant names. Using provided order.
#   warnings.warn(
# /Users/eabousam/opt/anaconda3/envs/forecasting-fit/lib/python3.9/site-packages/evofr/data/data_helpers.py:89: UserWarning: Omicron 21L not present in variant names. Using provided order.
#   warnings.warn(
# /Users/eabousam/opt/anaconda3/envs/forecasting-fit/lib/python3.9/site-packages/evofr/data/data_helpers.py:89: UserWarning: Omicron 21L not present in variant names. Using provided order.
#   warnings.warn(
# /Users/eabousam/opt/anaconda3/envs/forecasting-fit/lib/python3.9/site-packages/evofr/data/data_helpers.py:89: UserWarning: Omicron 21L not present in variant names. Using provided order.
#   warnings.warn(
# /Users/eabousam/opt/anaconda3/envs/forecasting-fit/lib/python3.9/site-packages/evofr/data/data_helpers.py:89: UserWarning: Omicron 21L not present in variant names. Using provided order.
#   warnings.warn(
# /Users/eabousam/opt/anaconda3/envs/forecasting-fit/lib/python3.9/site-packages/evofr/data/data_helpers.py:89: UserWarning: Omicron 21L not present in variant names. Using provided order.
#   warnings.warn(
# /Users/eabousam/opt/anaconda3/envs/forecasting-fit/lib/python3.9/site-packages/evofr/data/data_helpers.py:89: UserWarning: Omicron 21L not present in variant names. Using provided order.
#   warnings.warn(
# /Users/eabousam/opt/anaconda3/envs/forecasting-fit/lib/python3.9/site-packages/evofr/data/data_helpers.py:89: UserWarning: Omicron 21L not present in variant names. Using provided order.
#   warnings.warn(
