# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import matplotlib as mpl


FONT_SIZE = 12
AXES_SIZE = FONT_SIZE * 1.5
TICK_SIZE = FONT_SIZE * 1.25
LEGEND_SIZE = FONT_SIZE

my_rcParams = {
    "axes.spines.top": False,
    "axes.spines.right": False,
    "lines.linewidth": 5,
    "font.size": FONT_SIZE,
    "font.family": "Helvetica",
    "axes.titlesize": AXES_SIZE,
    "axes.labelsize": AXES_SIZE,
    "xtick.labelsize": TICK_SIZE,
    "ytick.labelsize": TICK_SIZE,
    "legend.fontsize": LEGEND_SIZE,
    "xtick.major.pad": FONT_SIZE / 2,
    "ytick.major.pad": FONT_SIZE / 2,
}

for k, v in my_rcParams.items():
    mpl.rcParams[k] = v

# %%
DATE_MIN = ...
DATE_MAX = ...

# %%
# Filter to sequences in this date range
# Group by country
# Plot average number of sequences per week in range

# %%
# https://data.nextstrain.org/files/ncov/open/metadata.tsv.gz
raw_metadata_reader = pd.read_csv(
    "../data/gisaid_metadata_pruned.tsv", 
    sep="\t",
    usecols=(
        "strain",
        "date",
        "date_submitted",
        "country",
        "division",
        "Nextstrain_clade"
        ),
    dtype={
        "country": "category",
        "division": "category",
        "Nextstrain_clade": "category",
        },
    chunksize=100000)

# %%
# Countries of interest
# All countries in order and then highlight countries of interest
#locations = ["USA", "Japan", "United Kingdom", "Australia", "Brazil", "South Africa"]
start_date = "2022-01-01"
end_date = "2022-12-31"

# Borrowing from John here
def clean_metadata(metadata):
    # Filter to countries
    #metadata = metadata[metadata["country"].isin(locations)]
    
    # Remove ambigious dates
    unambiguous_dates = (metadata["date"] != "?") & (metadata["date"].str.count("-") == 2)
    unambiguous_dates = unambiguous_dates & ~(metadata["date"].str.contains("X", na=True))
    metadata = metadata[unambiguous_dates].copy()
    
    # Filter to date range
    metadata["date"] = pd.to_datetime(metadata["date"])
    metadata["date_submitted"] = pd.to_datetime(metadata["date_submitted"])

    date_since_start_date = (metadata["date"] >= start_date)
    date_before_end_date = (metadata["date"] <= end_date)
    metadata = metadata[(date_since_start_date) & (date_before_end_date)].copy()
        
    # Filter records without NS clade
    metadata = metadata[~pd.isnull(metadata["Nextstrain_clade"])].copy()
    
    # Remove airport strain
    metadata = metadata[~(metadata["strain"].str.startswith("Japan/IC-"))]
    return metadata

# %%
metadata_chunks = [clean_metadata(chunk) for chunk in raw_metadata_reader]

# %%
metadata = pd.concat(metadata_chunks, ignore_index=True)
metadata
# Out:
#                                                     strain       date  \
# 0                               Afghanistan/barcode01/2022 2022-04-03
# 1                               Afghanistan/barcode02/2022 2022-03-28
# 2                               Afghanistan/barcode03/2022 2022-04-03
# 3                               Afghanistan/barcode04/2022 2022-04-05
# 4                               Afghanistan/barcode05/2022 2022-04-05
# ...                                                    ...        ...
# 6712273                         spain/PV-HUB-53446890/2022 2022-06-30
# 6712274  syrianhamster/India/DL-ICMR-MCL-22-856-HAM43LU... 2022-01-07
# 6712275  syrianhamster/India/DL-ICMR-MCL-22-856-HAM43LU... 2022-01-07
# 6712276                    tiger/USA/FL-22-000348-001/2022 2022-01-02
# 6712277                    tiger/USA/FL-22-000351-001/2022 2022-01-03
#
#         date_submitted      country        division Nextstrain_clade
# 0           2022-09-21  Afghanistan        Kandahar    21M (Omicron)
# 1           2022-09-21  Afghanistan        Kandahar              19A
# 2           2022-09-21  Afghanistan        Kandahar              19A
# 3           2022-09-21  Afghanistan        Kandahar    21L (Omicron)
# 4           2022-09-21  Afghanistan        Kandahar              19A
# ...                ...          ...             ...              ...
# 6712273     2022-07-06        Spain  Basque Country    21L (Omicron)
# 6712274     2022-07-18        India           Delhi    21L (Omicron)
# 6712275     2022-07-18        India           Delhi    21L (Omicron)
# 6712276     2022-03-04          USA         Florida      21J (Delta)
# 6712277     2022-03-04          USA         Florida      21J (Delta)
#
# [6712278 rows x 6 columns]

# %%
weekly_sequences = (metadata
        .groupby(["country", pd.Grouper(key='date', freq='W')])
        .size()
        .to_frame("sequences_per_week")
        .reset_index())
weekly_sequences = weekly_sequences.sort_values("sequences_per_week")

# %%
plot_df = weekly_sequences.groupby("country").agg({'sequences_per_week':['mean','sem']}).reset_index()
plot_df.columns = ['country', 'mean_seq_per_week', 'sem_seq_per_week']
plot_df = plot_df.sort_values("mean_seq_per_week")

# Export for plotting later
plot_df.to_csv("../data/down_scaled/weekly_sequences_by_country.tsv", sep="\t")

# %%
monthly_sequences = (metadata
        .groupby(["country", pd.Grouper(key='date', freq='M')])
        .size()
        .to_frame("sequences_per_month")
        .reset_index())
monthly_sequences.head()
# Out:
#        country       date  sequences_per_month
# 0  Afghanistan 2022-02-28                    4
# 1  Afghanistan 2022-03-31                    2
# 2  Afghanistan 2022-04-30                    7
# 3      Albania 2022-01-31                  195
# 4      Albania 2022-02-28                  349

# %%
avg_monthly_seq = monthly_sequences.groupby("country").agg({'sequences_per_month':['mean']}).reset_index()
avg_monthly_seq.columns = ['country', 'mean_seq_per_week']

# %%
filtered_countries = avg_monthly_seq[avg_monthly_seq["mean_seq_per_week"] > 100]["country"]
n_countries = len(filtered_countries)


fig = plt.figure(figsize=(24., 48.), constrained_layout=True)
spec = fig.add_gridspec(ncols= 5, nrows= (n_countries // 5) + 1)

def plot_country_sequencing_rates(ax, monthly_sequences, country):
    plot_df = monthly_sequences[monthly_sequences["country"] == country]
    ax.plot(plot_df.date, plot_df.sequences_per_month,)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=25)

    ax.set_ylabel("Sequences per month")
    ax.set_title(country)
    for axis in ['top','bottom','left','right']:
        ax.spines[axis].set_linewidth(4)

        
for i, country in enumerate(filtered_countries):
    if i == 0:
        ax = fig.add_subplot(spec[i])
    else:
        ax = fig.add_subplot(spec[i], sharex=ax)

    plot_country_sequencing_rates(ax, monthly_sequences, country)

fig.savefig("../manuscript/figures/sequence_per_month_2022.png")
# Out:
# /var/folders/27/fy80dyf90h520912n_x6g8nm0000gn/T/ipykernel_2429/385499677.py:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=25)
