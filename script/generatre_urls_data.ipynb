# %%
import fileinput
import requests
import git
from git import repo
import pandas as pd
import os

# %%
####get the log 

g = git.Git("../rt-from-frequency-dynamics")
full_commit = list(g.log("--follow","--pretty=short", "--", "data/omicron-countries-split/omicron-countries-split_location-case-counts.tsv").split('\n'))
commits = list(g.log("--follow","--pretty=%H", "--", "data/omicron-countries-split/omicron-countries-split_location-case-counts.tsv").split('\n'))
dates = list(g.log("--follow","--pretty=%as", "--", "data/omicron-countries-split/omicron-countries-split_location-case-counts.tsv").split('\n'))

full_commit
# Out:
# ['commit e0979214472cf137c50f3acde53f2b3eb4fb6048',
#  'Author: Trevor Bedford <trevor@bedford.io>',
#  '',
#  '    Omicron countries split data update Jun 22',
#  '',
#  'commit 282b5d209b797820b3bd85213b6fb23351f4da9f',
#  'Author: Trevor Bedford <trevor@bedford.io>',
#  '',
#  '    Omicron countries split data update Jun 14',
#  '',
#  'commit 79432f315e55a495879d9e3377f5546c293b860d',
#  'Author: Trevor Bedford <trevor@bedford.io>',
#  '',
#  '    Omicron countries split data update Jun 8',
#  '',
#  'commit 07b5ca983c8b0289328d859aa57d4c88609331a3',
#  'Author: Trevor Bedford <trevor@bedford.io>',
#  '',
#  '    Omicron countries split data update May 27',
#  '',
#  'commit c491e5d0ef44cc37c1ad0fdcd0a1eaba2ae2e673',
#  'Author: Trevor Bedford <trevor@bedford.io>',
#  '',
#  '    Omicron countries split data update May 25',
#  '',
#  'commit abbb43de19d0932950f397869f628aa3ff051eea',
#  'Author: Trevor Bedford <trevor@bedford.io>',
#  '',
# ...

# %%
commits
# Out:
# ['e0979214472cf137c50f3acde53f2b3eb4fb6048',
#  '282b5d209b797820b3bd85213b6fb23351f4da9f',
#  '79432f315e55a495879d9e3377f5546c293b860d',
#  '07b5ca983c8b0289328d859aa57d4c88609331a3',
#  'c491e5d0ef44cc37c1ad0fdcd0a1eaba2ae2e673',
#  'abbb43de19d0932950f397869f628aa3ff051eea',
#  'fa5f57816caaf088344f21f823640e8efc15dc99',
#  '0b1f332dc8ae7e2037a00d9501b88ccab71b2ebf',
#  'a810178b05d88a19a47529e1857616e49c75aa08',
#  '609b2e49bb6d11eabe9a90076c6243c90da8290c',
#  '037e639346afe1b99710fd607fee58bfdfe93800',
#  '2a6305a91700ce39a589ae3b5cf1edac4ac4b5e3',
#  'b5fc18a2d2f414c0929811c967b0810e55a234a6',
#  'da1671f7738d70d9fe66de5933e8a651de4eef55',
#  'fcf0752cb0e3664199f0fb52419de1ceeff65447',
#  '87660c45b26a5a58869b5b3cc9b180b43d676594',
#  '7a8b83b9935c6c0f9d961809db74e0a31040347e',
#  '646e2ac97ceb7427fb86be02fafff0862d68cc06',
#  'b581f811169d78cbe6ea7eb0af01d98af82fb925',
#  '552979935aaa01eb436b97ba15cc84f0faf06a43',
#  '4be20de26127b32787c2323ebce68c072df40f09',
# ...

# %%
replace_text= commits
#filedata = replace_text.read().split()
print(replace_text)
# Out:
# ['e0979214472cf137c50f3acde53f2b3eb4fb6048', '282b5d209b797820b3bd85213b6fb23351f4da9f', '79432f315e55a495879d9e3377f5546c293b860d', '07b5ca983c8b0289328d859aa57d4c88609331a3', 'c491e5d0ef44cc37c1ad0fdcd0a1eaba2ae2e673', 'abbb43de19d0932950f397869f628aa3ff051eea', 'fa5f57816caaf088344f21f823640e8efc15dc99', '0b1f332dc8ae7e2037a00d9501b88ccab71b2ebf', 'a810178b05d88a19a47529e1857616e49c75aa08', '609b2e49bb6d11eabe9a90076c6243c90da8290c', '037e639346afe1b99710fd607fee58bfdfe93800', '2a6305a91700ce39a589ae3b5cf1edac4ac4b5e3', 'b5fc18a2d2f414c0929811c967b0810e55a234a6', 'da1671f7738d70d9fe66de5933e8a651de4eef55', 'fcf0752cb0e3664199f0fb52419de1ceeff65447', '87660c45b26a5a58869b5b3cc9b180b43d676594', '7a8b83b9935c6c0f9d961809db74e0a31040347e', '646e2ac97ceb7427fb86be02fafff0862d68cc06', 'b581f811169d78cbe6ea7eb0af01d98af82fb925', '552979935aaa01eb436b97ba15cc84f0faf06a43', '4be20de26127b32787c2323ebce68c072df40f09', '830a38dc15d0671a61b650771065afa5dd0a8e85', '11a13db6913e394603a0cfde733c
# ...

# %%
BASE_URL = "https://raw.githubusercontent.com/blab/rt-from-frequency-dynamics/commitid/data/omicron-countries-split/omicron-countries-split_location-case-counts.tsv"

# %%
#generated_link = open('generated_links.txt', 'w')
commit_urls = []
for i in range(len(commits)):
    commit_urls.append(BASE_URL.replace('commitid',commits[i]))        
commit_urls
# Out:
# ['https://raw.githubusercontent.com/blab/rt-from-frequency-dynamics/e0979214472cf137c50f3acde53f2b3eb4fb6048/data/omicron-countries-split/omicron-countries-split_location-case-counts.tsv',
#  'https://raw.githubusercontent.com/blab/rt-from-frequency-dynamics/282b5d209b797820b3bd85213b6fb23351f4da9f/data/omicron-countries-split/omicron-countries-split_location-case-counts.tsv',
#  'https://raw.githubusercontent.com/blab/rt-from-frequency-dynamics/79432f315e55a495879d9e3377f5546c293b860d/data/omicron-countries-split/omicron-countries-split_location-case-counts.tsv',
#  'https://raw.githubusercontent.com/blab/rt-from-frequency-dynamics/07b5ca983c8b0289328d859aa57d4c88609331a3/data/omicron-countries-split/omicron-countries-split_location-case-counts.tsv',
#  'https://raw.githubusercontent.com/blab/rt-from-frequency-dynamics/c491e5d0ef44cc37c1ad0fdcd0a1eaba2ae2e673/data/omicron-countries-split/omicron-countries-split_location-case-counts.tsv',
# ...

# %%
for date, url in zip(dates,commit_urls):
    this_df = pd.read_csv(url, sep="\t")
    print(this_df)
    this_df.to_csv(f"case-counts_{date}.tsv", sep="\t")
# Out:
#             date   location   cases
# 0     2022-01-23  Australia   32234
# 1     2022-01-24  Australia   58022
# 2     2022-01-25  Australia   52920
# 3     2022-01-26  Australia   51016
# 4     2022-01-27  Australia   66223
# ...          ...        ...     ...
# 3745  2022-06-17        USA  158190
# 3746  2022-06-18        USA   14564
# 3747  2022-06-19        USA   15119
# 3748  2022-06-20        USA   50980
# 3749  2022-06-21        USA  155151
#
# [3750 rows x 3 columns]
#             date   location   cases
# 0     2022-01-15  Australia  112867
# 1     2022-01-16  Australia   59891
# 2     2022-01-17  Australia   84355
# 3     2022-01-18  Australia   84615
# 4     2022-01-19  Australia   67604
# ...          ...        ...     ...
# 3745  2022-06-09        USA  142023
# 3746  2022-06-10        USA  106156
# 3747  2022-06-11        USA   32160
# 3748  2022-06-12        USA   14819
# 3749  2022-06-13        USA  117279
#
# [3750 rows x 3 columns]
# ...

# %%
#Downloading datasets

url_list = open('generated_links.txt','r')
links = url_list.read()

for url in links:
    r = requests.get(url)
# Out:
# ---------------------------------------------------------------------------
# LocationParseError                        Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/models.py:384, in PreparedRequest.prepare_url(self, url, params)
#     383 try:
# --> 384     scheme, auth, host, port, path, query, fragment = parse_url(url)
#     385 except LocationParseError as e:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/util/url.py:394, in parse_url(url)
#     393 except (ValueError, AttributeError):
# --> 394     return six.raise_from(LocationParseError(source_url), None)
#     396 # For the sake of backwards compatibility we put empty
#     397 # string values for path if there are any defined values
#     398 # beyond the path in the URL.
#     399 # TODO: Remove this when we break backwards compatibility.
#
# File <string>:3, in raise_from(value, from_value)
#
# LocationParseError: Failed to parse: [
#
# ...
